# %% [markdown]
# # Line Graph

# %%
import matplotlib.pyplot as plt
import matplotlib.style

# %%
a = [1,2,3,4,5]
b = [2,4,6,8,10]
c = [3,6,9,12,15]
d = [5,10,15,20,25]

# %%
plt.plot(a,b)

# %%
plt.plot(a,c)

# %%
plt.plot(a,b , color = "purple")

# %%
plt.plot(a,b , color = "purple" , linewidth = 5)

# %%
plt.plot(a,b , color = "purple" , linewidth = 5 , linestyle = "-.")

# %%
plt.plot(a,b)
plt.xlim(0,15)
plt.ylim(0,20)
# Out:
# (0.0, 20.0)

# %%
plt.plot(a,b)
plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
# Out:
# Text(0, 0.5, 'Y - Axis')

# %%
plt.plot(a,b)
plt.xlabel("X - Axis")
plt.ylabel("Y - Axis");

# %%
plt.plot(a,b)
plt.xlabel("X - Axis" , color = "red" , fontsize = 20)
plt.ylabel("Y - Axis" , color = "blue", fontsize = "20.6")
# Out:
# Text(0, 0.5, 'Y - Axis')

# %%
plt.plot(a,b)
plt.plot(a,c)

# %%
plt.plot(a,b , color = "red", label="A,B Line")
plt.plot(a,c , color = "purple", label="A,C Line", linestyle="-.")
plt.grid(color="green", linestyle="--")
plt.legend(ncol=2)

# %%
plt.plot(a,b)
plt.grid(True)

# %%
plt.plot(a,b)
plt.grid(True , linestyle = "--" , color = "red")

# %%
plt.plot(a,b , markersize = 6 , linestyle = "--" , marker = "o")
plt.grid(True , linestyle = "--" , color = "red")

# %%
plt.plot(a,b , color = "red")
plt.plot(a,c , color = "purple")
plt.legend(["Red Line" , "Purple Line"])

# %%
plt.plot(a,b , color = "red" , label = "Red Line")
plt.plot(a,c , color = "purple" , label = "Purple Line")
plt.legend()

# %%
plt.plot(a,b , color = "red" , label = "Red Line")
plt.plot(a,c , color = "purple" , label = "Purple Line")
plt.legend( loc = "lower right" , fontsize = 10)

# %%
plt.plot(a,b , color = "red" , label = "Red Line")
plt.plot(a,c , color = "purple" , label = "Purple Line")
plt.legend( loc = "lower right" , fontsize = 10 , ncol = 2)

# %%
matplotlib.style.use("grayscale")
plt.plot(a,b , color = "red")
plt.plot(a,c , color = "purple")
plt.legend(["Red Line" , "Purple Line"])

# %%
matplotlib.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
matplotlib.style.use('ggplot')

# %%
plt.plot(a,a, label="Line number 1", color="red")
plt.plot(a,b, label="Line number 2", color="green")
plt.plot(a,c, label="Line number 3", color="blue")
plt.plot(a,d, label="Line number 4", color="yellow")
plt.legend()
plt.show()

# %%
plt.style.use("seaborn-v0_8-notebook")
plt.plot(a,a, label="Line number 1", color="red")
plt.plot(a,b, label="Line number 2", color="green")
plt.plot(a,c, label="Line number 3", color="blue")
plt.plot(a,d, label="Line number 4", color="yellow")
plt.legend()
plt.show()

# %% [markdown]
# # Scatter Plot:

# %%
plt.style.use("seaborn-v0_8")
plt.scatter(a,b)

# %%
plt.scatter(a,b,color = "red")

# %%
plt.scatter(a,b,color = "purple" , marker = ".")

# %%
plt.scatter(a,b,color = "purple" , marker = "1")

# %%
plt.scatter(a,b,color = "purple" , marker = "4")

# %%
plt.scatter(a,b,color = "purple" , marker = "4" , label = "Scatter Plot")
plt.legend()

# %%
plt.scatter(a,b,color = "purple" , marker = "4")
plt.legend(["SCATTER PLOT"])

# %%
plt.style.use("classic")
plt.scatter(a,b,color = "purple" , marker = "4" , label = "Scatter Plot")
plt.legend()

# %%
plt.style.use("classic")
plt.grid(True)
plt.scatter(a,b,color = "purple" , marker = "4" , label = "Scatter Plot")
plt.legend()

# %%
plt.style.use("classic")
plt.grid(True , color = "red" )
plt.scatter(a,b,color = "purple" , marker = "4" , label = "Scatter Plot")
plt.legend()

# %% [markdown]
# # Pie Chart:

# %%
plt.pie(a)
# Out:
# ([<matplotlib.patches.Wedge at 0x10ce60040>,
#   <matplotlib.patches.Wedge at 0x10ce21660>,
#   <matplotlib.patches.Wedge at 0x10ce60a90>,
#   <matplotlib.patches.Wedge at 0x10ce60fd0>,
#   <matplotlib.patches.Wedge at 0x10ce61510>],
#  [Text(1.0759623560663252, 0.22870288220353185, ''),
#   Text(0.7360435992131525, 0.8174593690559478, ''),
#   Text(-0.339918873399729, 1.0461621095732052, ''),
#   Text(-1.0759622304262273, -0.22870347329286142, ''),
#   Text(0.5500008201747041, -0.9526274706343256, '')])

# %%
plt.pie(a , labels = ["pizza" , "burgers" , "veg wraps" , "chicken" , "Juice"]);

# %%
plt.pie(a , labels = ["pizza" , "burgers" , "veg wraps" , "chicken" , "Juice"] , explode = [0,0.1,0,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x10cf3f430>,
#   <matplotlib.patches.Wedge at 0x10cf3f370>,
#   <matplotlib.patches.Wedge at 0x10cf3fdc0>,
#   <matplotlib.patches.Wedge at 0x10cf6c340>,
#   <matplotlib.patches.Wedge at 0x10cf6c880>],
#  [Text(1.0759623560663252, 0.22870288220353185, 'pizza'),
#   Text(0.8029566536870755, 0.8917738571519431, 'burgers'),
#   Text(-0.339918873399729, 1.0461621095732052, 'veg wraps'),
#   Text(-1.0759622304262273, -0.22870347329286142, 'chicken'),
#   Text(0.5500008201747041, -0.9526274706343256, 'Juice')])

# %%
plt.pie(a , labels = ["pizza" , "burgers" , "veg wraps" , "chicken" , "Juice"] , explode = [0,0.1,0,0,0] , colors = ['red' , 'black' , 'blue' , 'orange' , 'pink'])
# Out:
# ([<matplotlib.patches.Wedge at 0x115ae4310>,
#   <matplotlib.patches.Wedge at 0x115ae4250>,
#   <matplotlib.patches.Wedge at 0x115ae4d60>,
#   <matplotlib.patches.Wedge at 0x115ae52a0>,
#   <matplotlib.patches.Wedge at 0x115a42e60>],
#  [Text(1.0759623560663252, 0.22870288220353185, 'pizza'),
#   Text(0.8029566536870755, 0.8917738571519431, 'burgers'),
#   Text(-0.339918873399729, 1.0461621095732052, 'veg wraps'),
#   Text(-1.0759622304262273, -0.22870347329286142, 'chicken'),
#   Text(0.5500008201747041, -0.9526274706343256, 'Juice')])

# %%
ex = [0,0.1,0,0,0]
lbl = ["pizza" , "burgers" , "veg wraps" , "chicken" , "Juice"]
clr = ['red' , 'black' , 'blue' , 'orange' , 'pink']
plt.pie(a , labels =  lbl, explode =  ex, colors = clr);

# %%
ex = [0,0.1,0,0,0]
lbl = ["pizza" , "burgers" , "veg wraps" , "chicken" , "Juice"]
clr = ['#ffb3b3' , '#ccb3ff' , '#99ffbb' , '#ff6666' , '#9999ff']
plt.pie(a , labels =  lbl, explode =  ex, colors = clr)
plt.legend()

# %%
ex = [0,0.1,0,0,0]
lbl = ["pizza" , "burgers" , "veg wraps" , "chicken" , "Juice"]
clr = ['#ffb3b3' , '#ccb3ff' , '#99ffbb' , '#ff6666' , '#9999ff']
plt.pie(a , labels =  lbl, explode =  ex, colors = clr)
plt.legend(title = "My Title")

# %%
ex = [0,0.1,0,0,0]
lbl = ["pizza" , "burgers" , "veg wraps" , "chicken" , "Juice"]
clr = ['#ffb3b3' , '#ccb3ff' , '#99ffbb' , '#ff6666' , '#9999ff']
plt.pie(a , labels =  lbl, explode =  ex, colors = clr)
plt.title("Graph Title")
plt.legend(title = "Legend Title")
plt.savefig("PIE.jpg")
