# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.outer(np.linspace(-2, 2, 10), np.ones(10))
y = x.copy().T
z = np.cos(x**2 + y**3)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(x, y, z, cmap='viridis', edgecolor='green')
ax.set_title('Surface Plot')
plt.show()

# %%
def fun(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

x = np.linspace(-10, 10, 40)
y = np.linspace(-10, 10, 40)
X, Y = np.meshgrid(x, y)
Z = fun(X, Y)

fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, cmap='cool', alpha=0.8)

ax.set_title('3D Contour Plot')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

plt.show()

# %%
data = pd.read_csv("weather_data.csv")

# %%
data
# Out:
#    temperature  humidity
# 0           30        50
# 1           31        52
# 2           31        53
# 3           32        55
# 4           34        57
# 5           35        60
# 6           37        64
# 7           39        67
# 8           40        70

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data['temperature'])
# Out:
# pandas.core.series.Series

# %%
plt.plot(data, marker="o")

# %%
plt.plot(data, marker="o")
plt.legend(data)

# %%
plt.plot(data['temperature'], marker=".")
plt.legend(data)

# %%
plt.plot(data['humidity'], marker=".")
plt.legend(['humidity'])

# %%
data.loc[0]
# Out:
# temperature    30
# humidity       50
# Name: 0, dtype: int64

# %%
data.mean()
# Out:
# temperature    34.333333
# humidity       58.666667
# dtype: float64

# %%
data.median()
# Out:
# temperature    34.0
# humidity       57.0
# dtype: float64

# %%
plt.plot(data['temperature'], label="Temp.", marker="o")
plt.plot(data['humidity'], label="Humidity", marker="o")
plt.legend()

# %%
data_duplicates = pd.read_csv("weather_data_with_duplicates.csv")

# %%
data_duplicates
# Out:
#     temperature  humidity
# 0            30        50
# 1            31        52
# 2            31        53
# 3            32        55
# 4            34        57
# 5            35        60
# 6            37        64
# 7            39        67
# 8            40        70
# 9            34        57
# 10           35        60
# 11           37        64
# 12           39        67
# 13           40        70

# %%
data_duplicates.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# dtype: bool

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
new_data = data_duplicates.drop_duplicates()

# %%
new_data
# Out:
#    temperature  humidity
# 0           30        50
# 1           31        52
# 2           31        53
# 3           32        55
# 4           34        57
# 5           35        60
# 6           37        64
# 7           39        67
# 8           40        70

# %%
data == new_data
# Out:
#    temperature  humidity
# 0         True      True
# 1         True      True
# 2         True      True
# 3         True      True
# 4         True      True
# 5         True      True
# 6         True      True
# 7         True      True
# 8         True      True

# %%
data_duplicates
# Out:
#     temperature  humidity
# 0            30        50
# 1            31        52
# 2            31        53
# 3            32        55
# 4            34        57
# 5            35        60
# 6            37        64
# 7            39        67
# 8            40        70
# 9            34        57
# 10           35        60
# 11           37        64
# 12           39        67
# 13           40        70

# %%
data_duplicates.drop_duplicates( inplace = True )

# %%
data_duplicates
# Out:
#    temperature  humidity
# 0           30        50
# 1           31        52
# 2           31        53
# 3           32        55
# 4           34        57
# 5           35        60
# 6           37        64
# 7           39        67
# 8           40        70

# %%
data_missing = pd.read_csv("weather_data_with_missing_values.csv")

# %%
data_missing
# Out:
#    temperature  humidity
# 0         30.0      50.0
# 1         31.0       NaN
# 2         31.0      53.0
# 3          NaN      55.0
# 4         34.0      57.0
# 5         35.0       NaN
# 6         37.0      64.0
# 7          NaN      67.0
# 8         40.0      70.0

# %%
data_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   temperature  7 non-null      float64
#  1   humidity     7 non-null      float64
# dtypes: float64(2)
# memory usage: 272.0 bytes

# %%
new_data_1=data_missing.dropna()

# %%
new_data_1
# Out:
#    temperature  humidity
# 0         30.0      50.0
# 2         31.0      53.0
# 4         34.0      57.0
# 6         37.0      64.0
# 8         40.0      70.0
